# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
anscombe = sns.load_dataset("anscombe")
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
dataset_1 = anscombe[anscombe['dataset']=='I']
dataset_1
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
plt.plot(dataset_1['x'], dataset_1['y'])

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 'o')

# %%
dataset_2 = anscombe[anscombe['dataset']=='II']
dataset_3 = anscombe[anscombe['dataset']=='III']
dataset_4 = anscombe[anscombe['dataset']=='IV']

# %%
fig = plt.figure(figsize = (20, 10))

# %%
axes_1 = fig.add_subplot(2, 2, 1)
axes_2 = fig.add_subplot(2, 2, 2)
axes_3 = fig.add_subplot(2, 2, 3)
axes_4 = fig.add_subplot(2, 2, 4)

# %%
axes_1.plot(dataset_1['x'], dataset_1['y'], 'o')

# %%
fig

# %%
axes_1.plot(dataset_1['x'], dataset_1['y'], 'o')
axes_2.plot(dataset_2['x'], dataset_2['y'], 'o')
axes_3.plot(dataset_3['x'], dataset_3['y'], 'o')
axes_4.plot(dataset_4['x'], dataset_4['y'], 'o')

# %%
fig

# %%
axes_2.plot(dataset_1['x'], dataset_1['y'], 'o')

# %%
fig

# %%
axes_1.set_title("dataset 1")
axes_2.set_title("dataset 2")
axes_3.set_title("dataset 3")
axes_4.set_title("dataset 4")
# Out:
# Text(0.5,1,'dataset 4')

# %%
fig

# %%
fig.suptitle("Anscombe data")
# Out:
# Text(0.5,0.98,'Anscombe data')

# %%
fig

# %%
tips = sns.load_dataset("tips")

# %%
tips[:5]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Inicializa una figura plot
fig2 = plt.figure()
axes1 = fig2.add_subplot(1, 1, 1)

# %%
axes1.hist(tips['total_bill'], bins=10)
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <a list of 10 Patch objects>)

# %%
fig2

# %%
axes1.hist(tips['total_bill'], bins=20)
# Out:
# (array([ 1.,  6., 13., 29., 31., 37., 28., 23., 18., 13., 10.,  9.,  5.,
#          7.,  3.,  4.,  1.,  2.,  3.,  1.]),
#  array([ 3.07 ,  5.457,  7.844, 10.231, 12.618, 15.005, 17.392, 19.779,
#         22.166, 24.553, 26.94 , 29.327, 31.714, 34.101, 36.488, 38.875,
#         41.262, 43.649, 46.036, 48.423, 50.81 ]),
#  <a list of 20 Patch objects>)

# %%
fig2

# %%
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Frecuencia')
# Out:
# Text(3.2,0.5,'Frecuencia')

# %%
fig2

# %%
scatter_plt = plt.figure()

# %%
axes1 = scatter_plt.add_subplot(1, 1, 1)

# %%
axes1.scatter(tips['total_bill'], tips['tip'])

# %%
scatter_plt

# %%
axes1.set_title('Scatter plot de Total bill vs tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(3.2,0.5,'Tip')

# %%
scatter_plt

# %%
boxplot = plt.figure()

# %%
axes1 = boxplot.add_subplot(1, 1, 1)

# %%
tips[tips['sex'] == 'Female'][:5]
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 16       10.33  1.67  Female     No  Sun  Dinner     3

# %%
tips[tips['sex'] == 'Female']['tip'][:5]
# Out:
# 0     1.01
# 4     3.61
# 11    5.00
# 14    3.02
# 16    1.67
# Name: tip, dtype: float64

# %%
tips[tips['sex'] == 'Male']['tip'][:5]
# Out:
# 1    1.66
# 2    3.50
# 3    3.31
# 5    4.71
# 6    2.00
# Name: tip, dtype: float64

# %%
subdata = [tips[tips['sex'] == 'Female']['tip'][:5], tips[tips['sex'] == 'Male']['tip'][:5]]

# %%
axes1.boxplot(subdata, labels = ['Femenino', 'Masculino'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x1a214b1780>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a214bab00>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1a214c37b8>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x1a214c3390>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x1a214ba240>,
# ...
#   <matplotlib.lines.Line2D at 0x1a214cf470>]}

# %%
boxplot

# %%
axes1.set_title('Boxplot de tips por sexo')
axes1.set_xlabel('Sexo')
axes1.set_ylabel('Tip')
# Out:
# Text(3.2,0.5,'Tip')

# %%
boxplot

# %%
hist, ax = plt.subplots()
ax = sns.distplot(tips['total_bill'])
ax.set_title('Total')
plt.show()

# %%
hist, ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], rug=True)
ax.set_title('Total')
plt.show()

# %%
count, ax = plt.subplots()
ax = sns.countplot('day', data = tips)
ax.set_title('Cuenta por día')
plt.show()

# %%
scatter, ax = plt.subplots()
ax = sns.regplot(x = 'total_bill', y = 'tip', data = tips)
ax.set_title('Scatter plot')
ax.set_xlabel('Total')
ax.set_ylabel('Tip')
plt.show()

# %%
joint = sns.jointplot(x = 'total_bill', y = 'tip', data = tips)
joint.set_axis_labels(xlabel = 'Total Bill', ylabel = 'Tip')

# %%
hexbin = sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind = 'hex')
hexbin.set_axis_labels(xlabel = 'Total Bill', ylabel = 'Tip')

# %%
kde, ax = plt.subplots()
ax = sns.kdeplot(data = tips['total_bill'], data2=tips['tip'])

# %%
kde, ax = plt.subplots()
ax = sns.kdeplot(data = tips['total_bill'], data2=tips['tip'], shade = True)

# %%
kde_joint = sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind = 'kde')

# %%
bar, ax = plt.subplots()
ax = sns.barplot(x = 'time', y = 'total_bill', data = tips)

# %%
import numpy

# %%
bar, ax = plt.subplots()
ax = sns.barplot(x = 'time', y = 'total_bill', data = tips, estimator = numpy.std)

# %%
box, ax = plt.subplots()
ax = sns.boxplot(x = 'time', y = 'total_bill', data = tips)

# %%
violin, ax = plt.subplots()
ax = sns.violinplot(x = 'time', y = 'total_bill', data = tips)

# %%
violin, ax = plt.subplots()
ax = sns.violinplot(x = 'time', y = 'total_bill', data = tips, hue = 'sex')

# %%
violin, ax = plt.subplots()
ax = sns.violinplot(x = 'time', y = 'total_bill', data = tips, hue = 'sex', split = True)

# %%
fig = sns.pairplot(tips)
