# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %%
Table.read_table('db/conacyt/_data/estados.csv')
# Out:
# id   | nombre                 | ama                 | gompertz            | abrev | obs_ama                                 | obs_gz
# 1    | Aguascalientes         | Aguascalientes      | Aguascalientes      | AGU   | nan                                     | nan
# 2    | Baja California        | Baja California     | Baja California     | BC    | nan                                     | nan
# 3    | Baja California Sur    | Baja California Sur | Baja California Sur | BCS   | nan                                     | nan
# 4    | Campeche               | Campeche            | Campeche            | CAM   | nan                                     | nan
# 7    | Chiapas                | Chiapas             | Chiapas             | CHP   | nan                                     | nan
# 8    | Chihuahua              | Chihuahua           | Chihuahua           | CHH   | nan                                     | nan
# ...

# %%
# Municipal
Table.read_table('db/conacyt/municipal/top15_municipio_fecha_ing/municipal_01_fecing_fecha.csv')
# Out:
# fecha_ing  | condia_01001 | condia_01002 | condia_01003 | condia_01004 | condia_01005 | condia_01006 | condia_01007 | condia_01008 | condia_01009 | condia_01010 | condia_01011 | conacu_01001 | conacu_01002 | conacu_01003 | conacu_01004 | conacu_01005 | conacu_01006 | conacu_01007 | conacu_01008 | conacu_01009 | conacu_01010 | conacu_01011 | promov_01001 | promov_01002 | promov_01003 | promov_01004 | promov_01005 | promov_01006 | promov_01007 | promov_01008 | promov_01009 | promov_01010 | promov_01011 | condiatas_01001 | condiatas_01002 | condiatas_01003 | condiatas_01004 | condiatas_01005 | condiatas_01006 | condiatas_01007 | condiatas_01008 | condiatas_01009 | condiatas_01010 | condiatas_01011 | conacutas_01001 | conacutas_01002 | conacutas_01003 | conacutas_01004 | conacutas_01005 | conacutas_01006 | conacutas_01007 | conacutas_01008 | conacutas_01009 | conacutas_01010 | conacutas_01011
# ...

# %%
# Nacional
Table.read_table('db/conacyt/internacional/nacional_fecinicio_fecha.csv').show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
# ...

# %%
#Table.read_table('db/conacyt/municipal/top15_municipio_fecha_sin/municipal_01_fecsin_fecha.csv')

# %%
#Table.read_table('db/conacyt/municipal/top15_municipio_fecha_sin_dia/municipal_01_fecsin_dia.csv')

# %%
#Table.read_table('db/conacyt/municipal/top15_municipio_fecing_dia/municipal_01_fecing_dia.csv')

# %%
#Table.read_table('db/conacyt/internacional/nacional_fecingreso_fecha.csv')
