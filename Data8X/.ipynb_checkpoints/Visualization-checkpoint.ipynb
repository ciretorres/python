# %%
from datascience import *
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# # Visualization

# %% [markdown]
# ### Scatter Plots

# %%
actors = Table.read_table('db/actors.csv')
actors
# Out:
# Actor              | Total Gross | Number of Movies | Average per Movie | #1 Movie
# Harrison Ford      | 4871.7      | 41               | 118.8             | Star Wars: The Force Awakens
# Samuel L. Jackson  | 4772.8      | 69               | 69.2              | The Avengers
# Morgan Freeman     | 4468.3      | 61               | 73.3              | The Dark Knight
# Tom Hanks          | 4340.8      | 44               | 98.7              | Toy Story 3
# Robert Downey, Jr. | 3947.3      | 53               | 74.5              | The Avengers
# Eddie Murphy       | 3810.4      | 38               | 100.3             | Shrek 2
# Tom Cruise         | 3587.2      | 36               | 99.6              | War of the Worlds
# Johnny Depp        | 3368.6      | 45               | 74.9              | Dead Man's Chest
# Michael Caine      | 3351.5      | 58               | 57.8              | The Dark Knight
# Scarlett Johansson | 3341.2      | 37               | 90.3              | The Avengers
# ... (40 rows omitted)

# %%
actors.scatter('Number of Movies', 'Total Gross')

# %%
actors.scatter('Number of Movies', 'Average per Movie')

# %%
no_outlier = actors.where('Number of Movies', are.above(10))
no_outlier.scatter('Number of Movies', 'Average per Movie')

# %%
actors.where('Number of Movies', are.above(60))
# Out:
# Actor             | Total Gross | Number of Movies | Average per Movie | #1 Movie
# Samuel L. Jackson | 4772.8      | 69               | 69.2              | The Avengers
# Morgan Freeman    | 4468.3      | 61               | 73.3              | The Dark Knight
# Robert DeNiro     | 3081.3      | 79               | 39                | Meet the Fockers
# Liam Neeson       | 2942.7      | 63               | 46.7              | The Phantom Menace

# %%
actors.where('Number of Movies', are.below(10))
# Out:
# Actor           | Total Gross | Number of Movies | Average per Movie | #1 Movie
# Anthony Daniels | 3162.9      | 7                | 451.8             | Star Wars: The Force Awakens

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br>

# %% [markdown]
# ### Lines Graphs

# %%
movies_by_year = Table.read_table('db/movies_by_year.csv')
movies_by_year = movies_by_year.select(0, 1, 5, 9)
movies_by_year
# Out:
# Year | Total Gross | Number of Movies | #1 Movie
# 2015 | 11129.4     | 705              | Star Wars: The Force Awakens
# 2014 | 10361.2     | 706              | American Sniper
# 2013 | 10924.6     | 688              | Catching Fire
# 2012 | 10837.6     | 669              | The Avengers
# 2011 | 10174.2     | 602              | Harry Potter / Deathly Hallows (P2)
# 2010 | 10565.6     | 537              | Toy Story 3
# 2009 | 10595.5     | 521              | Avatar
# 2008 | 9630.7      | 607              | The Dark Knight
# 2007 | 9663.8      | 631              | Spider-Man 3
# 2006 | 9209.5      | 608              | Dead Man's Chest
# ... (26 rows omitted)

# %%
movies_by_year.plot('Year', 'Number of Movies')

# %%
century_21 = movies_by_year.where('Year', are.above(1999))

# %%
century_21.plot('Year', 'Number of Movies')

# %%
century_21.plot('Year', 'Total Gross')

# %%
century_21.where('Year', are.equal_to(2009))
# Out:
# Year | Total Gross | Number of Movies | #1 Movie
# 2009 | 10595.5     | 521              | Avatar
