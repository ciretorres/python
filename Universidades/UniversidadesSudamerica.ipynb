# %%
# Script para filtrar las mejores universidades de sudamerica y 
# que tienen convenio con la unam o México

# Referencias
# http://www.politicas.posgrado.unam.mx/sitio/reposmov/Listado%20de%20Convenios.pdf
# https://disur.edu.ar/miembros/#mapeo-regional
# http://www.redmacro.unam.mx/universidades.html
# https://www.facebook.com/photo?fbid=941504817671492&set=pcb.941504854338155

# %%
uniColombia = ['Pontificia Universidad Javeriana (PUJ)',
  'Universidad Autónoma Latinoamericana (UNAULA)',
  'Universidad Autónoma de Bucaramanga (UNAB)',
  'Universidad Autónoma de Colombia (FUAC)',
  'Universidad Autónoma del Caribe (UAC)',
  'Universidad Católica de Manizales (UCM)',
  'Universidad Central (UC)',
  'Universidad EAFIT (EAFIT)',
  'Universidad EIA',
  'Universidad El Bosque (UNBOSQUE)',
  'Universidad INCCA de Colombia',
  'Universidad Libre (UNILIBRE)',
  'Universidad Manuela Beltrán (UMB)',
  'Universidad Metropolitana',
  'Universidad Nacional de Colombia (UNAL)',
  'Universidad Pedagógica y Tecnológica de Colombia (UPTC)',
  'Universidad Pontificia Bolivariana (UPB)',
  'Universidad Santiago de Cali (USC)',
  'Universidad Santo Tomas (USTA)',
  'Universidad Sergio Arboleda (USERGIOARBOLEDA)',
  'Universidad Tecnológica de Pereira (UTP)',
  'Universidad de Antioquia (UDEA)',
  'Universidad de Bogotá Jorge Tadeo Lozano (UTADEO)',
  'Universidad de Caldas (UCALDAS)',
  'Universidad de Córdoba (UNICORDOBA)',
  'Universidad de La Amazonia (UNIAMAZONIA)',
  'Universidad de La Sabana (UNISABANA)',
  'Universidad de Los Llanos (UNILLANOS)',
  'Universidad de Medellín (UDEM)',
  'Universidad de Nariño (UDENAR)',
  'Universidad de Pamplona (UDP)',
  'Universidad de Quindío',
  'Universidad de San Buenaventura (USB)',
  'Universidad de Santander (UDES)',
  'Universidad de los Andes (UNIANDES)',
  'Universidad del Cauca (UNICAUCA)',
  'Universidad del Magdalena (UNIMAGDALENA)',
  'Universidad del Norte (UNINORTE)',
  'Universidad del Rosario (UROSARIO)',
  'Universidad del Tolima (UT)',
  'Universidad del Valle (UNIVALLE)']

sorteduniColombia = sorted(uniColombia)
len(sorteduniColombia), sorteduniColombia
# Out:
# (41,
#  ['Pontificia Universidad Javeriana (PUJ)',
#   'Universidad Autónoma Latinoamericana (UNAULA)',
#   'Universidad Autónoma de Bucaramanga (UNAB)',
#   'Universidad Autónoma de Colombia (FUAC)',
#   'Universidad Autónoma del Caribe (UAC)',
#   'Universidad Católica de Manizales (UCM)',
#   'Universidad Central (UC)',
#   'Universidad EAFIT (EAFIT)',
#   'Universidad EIA',
#   'Universidad El Bosque (UNBOSQUE)',
#   'Universidad INCCA de Colombia',
#   'Universidad Libre (UNILIBRE)',
#   'Universidad Manuela Beltrán (UMB)',
#   'Universidad Metropolitana',
#   'Universidad Nacional de Colombia (UNAL)',
#   'Universidad Pedagógica y Tecnológica de Colombia (UPTC)',
#   'Universidad Pontificia Bolivariana (UPB)',
#   'Universidad Santiago de Cali (USC)',
#   'Universidad Santo Tomas (USTA)',
#   'Universidad Sergio Arboleda (USERGIOARBOLEDA)',
#   'Universidad Tecnológica de Pereira (UTP)',
#   'Universidad de Antioquia (UDEA)',
# ...

# %%
uniArgentina =  ['Universidad Católica de Córdoba (UCC)',
  'Universidad Nacional Arturo Jauretche (UNAJ)',
  'Universidad Nacional de Avellaneda (UNDAV)',
  'Universidad Nacional de Cuyo (UNCUYO)',
  'Universidad Nacional de Córdoba (UNC)',
  'Universidad Nacional de Formosa (UNAF)',
  'Universidad Nacional de General San Martín (UNSAM)',
  'Universidad Nacional de General Sarmiento (UNGS)',
  'Universidad Nacional de Hurlingham (UNAHUR)',
  'Universidad Nacional de José Clemente Paz',
  'Universidad Nacional de La Plata (UNLP)',
  'Universidad Nacional de Lanús (UNLA)',
  'Universidad Nacional de Luján (UNLU)',
  'Universidad Nacional de Mar del Plata (UNMDP)',
  'Universidad Nacional de Nordeste (UNNE)',
  'Universidad Nacional de Rafaela',
  'Universidad Nacional de Rosario (UNR)',
  'Universidad Nacional de Río Cuarto (UNRC)',
  'Universidad Nacional de Río Negro (UNRN)',
  'Universidad Nacional de Salta (UNSA)',
  'Universidad Nacional de San Juan (UNSJ)',
  'Universidad Nacional de San Luis (UNSL)',
  'Universidad Nacional de Tucumán (UNT)',
  'Universidad Nacional de Villa María (UNVM)',
  'Universidad Nacional del Comahue (UNCOMA)',
  'Universidad Nacional del Litoral (UNL)',
  'Universidad Nacional del Sur (UNS)',
  'Universidad de Belgrano (UB)',
  'Universidad de Buenos Aires (UBA)',
  'Universidad de Congreso (UC)',
  'Universidad de Mendoza (UM)',
  'Universidad de Misiones (UNAM)']
sorteduniArgentina = sorted(uniArgentina)
len(sorteduniArgentina), sorteduniArgentina
# Out:
# (32,
#  ['Universidad Católica de Córdoba (UCC)',
#   'Universidad Nacional Arturo Jauretche (UNAJ)',
#   'Universidad Nacional de Avellaneda (UNDAV)',
#   'Universidad Nacional de Cuyo (UNCUYO)',
#   'Universidad Nacional de Córdoba (UNC)',
#   'Universidad Nacional de Formosa (UNAF)',
#   'Universidad Nacional de General San Martín (UNSAM)',
#   'Universidad Nacional de General Sarmiento (UNGS)',
#   'Universidad Nacional de Hurlingham (UNAHUR)',
#   'Universidad Nacional de José Clemente Paz',
#   'Universidad Nacional de La Plata (UNLP)',
#   'Universidad Nacional de Lanús (UNLA)',
#   'Universidad Nacional de Luján (UNLU)',
#   'Universidad Nacional de Mar del Plata (UNMDP)',
#   'Universidad Nacional de Nordeste (UNNE)',
#   'Universidad Nacional de Rafaela',
#   'Universidad Nacional de Rosario (UNR)',
#   'Universidad Nacional de Río Cuarto (UNRC)',
#   'Universidad Nacional de Río Negro (UNRN)',
#   'Universidad Nacional de Salta (UNSA)',
# ...

# %%
uniChile = ['Pontificia Universidad Católica de Chile (UC)',
  'Pontificia Universidad Católica de Valparaíso (PUCV)',
  'Universidad Arturo Prat',
  'Universidad Austral (UACH)',
  'Universidad Bolivariana',
  'Universidad Católica de la Santísima Concepción (UCSC)',
  'Universidad Católica del Maule',
  'Universidad Católica del Norte (UCN)',
  'Universidad Central',
  'Universidad Finis Terrae',
  'Universidad Mayor',
  'Universidad Tecnológica',
  'Universidad Técnica Federico Santa María (USM)',
  'Universidad de Artes, Ciencias y Comunicación',
  'Universidad de Chile (UCHILE)',
  'Universidad de Concepción (UDEC)',
  'Universidad de Los Lagos',
  'Universidad de Magallanes (UMAG)',
  'Universidad de Santiago de Chile (USACH)',
  'Universidad de Tapacará (UTA)',
  'Universidad de Valparaíso (UV)',
  'Universidad de la Frontera (UFRO)',
  'Universidad de la Serena (USERENA)',
  'Universidad del Bío Bío (UBIOBIO)',
  'Universidad del Pacífico']
sortedUniChile = sorted(uniChile)
len(sortedUniChile), sortedUniChile
# Out:
# (25,
#  ['Pontificia Universidad Católica de Chile (UC)',
#   'Pontificia Universidad Católica de Valparaíso (PUCV)',
#   'Universidad Arturo Prat',
#   'Universidad Austral (UACH)',
#   'Universidad Bolivariana',
#   'Universidad Católica de la Santísima Concepción (UCSC)',
#   'Universidad Católica del Maule',
#   'Universidad Católica del Norte (UCN)',
#   'Universidad Central',
#   'Universidad Finis Terrae',
#   'Universidad Mayor',
#   'Universidad Tecnológica',
#   'Universidad Técnica Federico Santa María (USM)',
#   'Universidad de Artes, Ciencias y Comunicación',
#   'Universidad de Chile (UCHILE)',
#   'Universidad de Concepción (UDEC)',
#   'Universidad de Los Lagos',
#   'Universidad de Magallanes (UMAG)',
#   'Universidad de Santiago de Chile (USACH)',
#   'Universidad de Tapacará (UTA)',
#   'Universidad de Valparaíso (UV)',
#   'Universidad de la Frontera (UFRO)',
#   'Universidad de la Serena (USERENA)',
#   'Universidad del Bío Bío (UBIOBIO)',
# ...
